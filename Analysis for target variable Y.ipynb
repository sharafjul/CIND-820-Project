# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load data from a csv file

# Loading data that includes column Y
# Column Y was converted from raised_amount_usd to "YES" or "NO"
filename = '/Users/administrator/Desktop/CIND820 Big Data Analytics Project/datanerd-startup-venture-funding/data/investments1.csv'
df = pd.read_csv(filename)
df
# Out:
#                           company_permalink           company_name  \
# 0              /organization/test-company-3           test company
# 1       /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 2                    /organization/abo-data               ABO Data
# 3                    /organization/abo-data               ABO Data
# 4                        /organization/ikro                   Ikro
# ...                                     ...                    ...
# 114501               /organization/helpling               Helpling
# 114502                /organization/appknox                Appknox
# 114503                  /organization/strap                  Strap
# 114504                  /organization/strap                  Strap
# 114505            /organization/vonjour-com                Vonjour
#
#                                     company_category_list  \
# 0                                                     NaN
# ...

# %%
df.shape
# Out:
# (114506, 25)

# %%
#descriptive statistics for Y

# %%
df.Y.value_counts()
# Out:
# Yes    101091
# No      13415
# Name: Y, dtype: int64

# %%
df.Y.value_counts(normalize=True)
# Out:
# Yes    0.882845
# No     0.117155
# Name: Y, dtype: float64

# %%
df.Y.value_counts().plot(kind="bar")
plt.title("Value counts of the target variable")
plt.xlabel("Y")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### the range of Y by each funding round type

# %%
plt.figure(figsize=[12,14])
features=["funding_round_type"]
n=1
for f in features:
    plt.subplot(4,2,n)
    sns.countplot(x=f, hue='Y', edgecolor="black", alpha=0.7, data=df)
    sns.despine()
    plt.title("Countplot of {}  by y".format(f))
    n=n+1
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### the range of Y by each of selective funding round type - Venture, Seed, Private Equity and Angel

# %%
# Filter the data which contains only these round type
df_new = df[(df['funding_round_type']=='venture')|
      (df['funding_round_type']=='seed')|
      (df['funding_round_type']=='angel')|
      (df['funding_round_type']=='private_equity')]

# %%
plt.figure(figsize=[12,14])
features=["funding_round_type"]
n=1
for f in features:
    plt.subplot(4,2,n)
    sns.countplot(x=f, hue='Y', edgecolor="black", alpha=0.7, data=df_new)
    sns.despine()
    plt.title("Countplot of {}  by y".format(f))
    n=n+1
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()
